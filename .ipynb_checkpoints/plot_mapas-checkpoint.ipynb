# %%
#!pip install -q geopandas

# %%
import geopandas as gpd
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt

# %%
database_path = "/home/ubuntu/base_dados/geopandas/lim_unidade_federacao_a.shp"

# %%
map_df = gpd.read_file(database_path)
map_df.plot()

# %%
map_df.head()
# Out:
#              nome nomeabrev geometriaa sigla geocodigo  id_produto id_element  \
# 0           Bahia     Bahia        Não    BA        29    250014.0       None
# 1            Pará      None       None    PA        15         NaN       None
# 2  Rio de Janeiro      None       None    RJ        33    250000.0       None
# 3       São Paulo      None       None    SP        35    250000.0       None
# 4  Espírito Santo      None       None    ES        32    250000.0       None
#
#                                             geometry
# 0  MULTIPOLYGON (((-38.71080 -17.96966, -38.70848...
# 1  MULTIPOLYGON (((-46.45928 -0.90961, -46.45936 ...
# 2  MULTIPOLYGON (((-43.55929 -23.08050, -43.55938...
# 3  MULTIPOLYGON (((-45.13777 -23.79018, -45.13777...
# 4  MULTIPOLYGON (((-28.85365 -20.47547, -28.85372...

# %%
df_casos_ano_uf = "/home/ubuntu/Geracao_profiling/base_casos_ano_uf.csv"
df = pd.read_csv(df_casos_ano_uf)
df.shape
# Out:
# (216, 5)

# %%
df.head()
# Out:
#     ANO  UF  DENGUE  CHIKUNGUNYA  OUTRAS_DOENCAS
# 0  2013  PB    6061            0            3455
# 1  2013  PE    3211            0            7890
# 2  2013  RN    7345            0            4281
# 3  2013  AC     766            0            2459
# 4  2013  RO    3419            0            2746

# %%
vmin=df.DENGUE.min()
vmax=df.DENGUE.max()
for ano in range (2013,2021) :
    df_ano = df[(df.ANO == ano)]
    merged = map_df.set_index('sigla').join(df_ano.set_index('UF'))
    merged.head()
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))
    ax.axis('off')
    #ax.set_title(f'Casos de dengue {ano}', fontdict={'fontsize': '25', 'fontweight' : '3'})
    # Create colorbar as a legend
    sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
    # empty array for the data range
    sm._A = []
    # add the colorbar to the figure
    cbar = fig.colorbar(sm)
    merged.plot(column='DENGUE', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)
    fig.savefig(f'/home/ubuntu/Geracao_profiling/Mapas/dengue/dengue{ano}.jpg' , dpi=300)

# %%
vmin=df.CHIKUNGUNYA.min()
vmax=df.CHIKUNGUNYA.max()
for ano in range (2015,2021) :
    df_ano = df[(df.ANO == ano)]
    merged = map_df.set_index('sigla').join(df_ano.set_index('UF'))
    merged.head()
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))
    ax.axis('off')
    #ax.set_title(f'Casos de chikungunya {ano}', fontdict={'fontsize': '25', 'fontweight' : '3'})
    # Create colorbar as a legend
    sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
    # empty array for the data range
    sm._A = []
    # add the colorbar to the figure
    cbar = fig.colorbar(sm)
    merged.plot(column='CHIKUNGUNYA', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)
    fig.savefig(f'/home/ubuntu/Geracao_profiling/Mapas/chika/chika{ano}.jpg' , dpi=300)

# %%
vmin=df.OUTRAS_DOENCAS.min()
vmax=df.OUTRAS_DOENCAS.max()
for ano in range (2013,2021) :
    df_ano = df[(df.ANO == ano)]
    merged = map_df.set_index('sigla').join(df_ano.set_index('UF'))
    merged.head()
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))
    ax.axis('off')
    #ax.set_title(f'Casos inconclusivos e/ou descartados  {ano}', fontdict={'fontsize': '25', 'fontweight' : '3'})
    # Create colorbar as a legend
    sm = plt.cm.ScalarMappable(cmap='Greens', norm=plt.Normalize(vmin=vmin, vmax=vmax))
    # empty array for the data range
    sm._A = []
    # add the colorbar to the figure
    cbar = fig.colorbar(sm)
    merged.plot(column='OUTRAS_DOENCAS', cmap='Greens', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)
    fig.savefig(f'/home/ubuntu/Geracao_profiling/Mapas/outros/outros{ano}.jpg' , dpi=300)
